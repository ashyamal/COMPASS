# %%
import pandas as pd
from glob import glob
import os

from rnanorm.datasets import load_toy_data
from rnanorm import FPKM, TPM, CPM, TMM 

# load the gene length
gtf_path = '/n/data1/hms/dbmi/zitnik/lab/users/was966/ITRP/GENCODE/release_36/HS.gencode.v36.annotation.gtf'
tpm = TPM(gtf_path).set_output(transform="pandas")

out_dir='/n/data1/hms/dbmi/zitnik/lab/users/was966/ITRP/fastaq/Gide/STAR/'
outs = glob(os.path.join(out_dir, "*ReadsPerGene.out.tab"))


counts=[]
for out in outs:
    ids = os.path.basename(out).replace('ReadsPerGene.out.tab', '')
    df = pd.read_csv(out,sep='\t', header=None)
    df.columns=['geneid', 'unstranded_counts', 'unstranded_counts_1st','unstranded_counts_2nd']
    df = df.iloc[4:].set_index('geneid')
    cts = df.unstranded_counts
    cts.name = ids
    counts.append(cts)

## counts, TPM, TMM
df_counts = pd.concat(counts,axis=1).T
df_tpm = tpm.fit_transform(df_counts)

df_tpm
# Out:
#             ENSG00000223972.5  ENSG00000227232.5  ENSG00000278267.1  \
# ERR2208944           0.460737          19.821755           0.000000
# ERR2208928           0.000000          25.382838           2.271609
# ERR2208949           0.069637          43.552412           0.000000
# ERR2208900           0.172087           9.672981           0.000000
# ERR2208922           0.000000           2.360453           1.617126
# ...                       ...                ...                ...
# ERR2208936           0.000000           4.730777           0.000000
# ERR2208974           0.000000          21.034862           0.000000
# ERR2208904           0.000000          12.851211           0.968969
# ERR2208951           0.000000          15.960204           0.000000
# ERR2208926           0.000000          11.701914           0.000000
#
#             ENSG00000243485.5  ENSG00000284332.1  ENSG00000237613.2  \
# ERR2208944                0.0                0.0           0.109294
# ERR2208928                0.0                0.0           0.000000
# ERR2208949                0.0                0.0           0.297342
# ERR2208900                0.0                0.0           0.263771
# ERR2208922                0.0                0.0           0.000000
# ...                       ...                ...                ...
# ERR2208936                0.0                0.0           0.000000
# ERR2208974                0.0                0.0           1.933767
# ERR2208904                0.0                0.0           0.000000
# ERR2208951                0.0                0.0           0.311691
# ERR2208926                0.0                0.0           0.000000
#
#             ENSG00000268020.3  ENSG00000240361.2  ENSG00000186092.6  \
# ERR2208944                0.0                0.0                0.0
# ERR2208928                0.0                0.0                0.0
# ERR2208949                0.0                0.0                0.0
# ERR2208900                0.0                0.0                0.0
# ERR2208922                0.0                0.0                0.0
# ...                       ...                ...                ...
# ERR2208936                0.0                0.0                0.0
# ERR2208974                0.0                0.0                0.0
# ERR2208904                0.0                0.0                0.0
# ERR2208951                0.0                0.0                0.0
# ERR2208926                0.0                0.0                0.0
#
#             ENSG00000238009.6  ...  ENSG00000198886.2  ENSG00000210176.1  \
# ERR2208944           0.000000  ...         133.036440           0.000000
# ERR2208928           0.000000  ...         253.675132           0.000000
# ERR2208949           0.000000  ...         223.052187           1.751014
# ERR2208900           0.024656  ...         219.469413           1.331418
# ERR2208922           0.000000  ...        1119.515705           3.187378
# ...                       ...  ...                ...                ...
# ERR2208936           0.163364  ...         229.695608           0.000000
# ERR2208974           0.000000  ...         206.417202           1.897956
# ERR2208904           0.000000  ...         107.967613           0.477463
# ERR2208951           0.000000  ...          71.688921           0.000000
# ERR2208926           0.077145  ...        2510.420247          10.414549
#
#             ENSG00000210184.1  ENSG00000210191.1  ENSG00000198786.2  \
# ERR2208944           0.000000           0.000000          69.629485
# ERR2208928           0.000000           0.000000         217.297235
# ERR2208949           0.000000           0.000000         118.886282
# ERR2208900           1.167811           0.323478         139.272015
# ERR2208922           0.000000           0.000000         332.563864
# ...                       ...                ...                ...
# ERR2208936           0.000000           0.000000         116.733412
# ERR2208974           0.000000           0.000000         112.023410
# ERR2208904           0.558389           0.000000          60.762696
# ERR2208951           0.000000           0.000000          39.997631
# ERR2208926           2.435945           0.000000         715.431241
#
#             ENSG00000198695.2  ENSG00000210194.1  ENSG00000198727.2  \
# ERR2208944          45.171249                0.0          67.957710
# ERR2208928         135.050420                0.0         201.175794
# ERR2208949          86.760220                0.0          78.887687
# ERR2208900         118.203257                0.0          75.402463
# ERR2208922         272.712079                0.0         400.922453
# ...                       ...                ...                ...
# ERR2208936         104.347433                0.0         120.431662
# ERR2208974          83.314856                0.0          76.555337
# ERR2208904          48.695766                0.0          73.223821
# ERR2208951          21.530572                0.0          36.047087
# ERR2208926         434.994885                0.0         883.863884
#
#             ENSG00000210195.2  ENSG00000210196.2
# ERR2208944                0.0           7.837047
# ERR2208928                0.0           0.000000
# ERR2208949                0.0           7.107055
# ERR2208900                0.0          34.112682
# ERR2208922                0.0           9.702754
# ...                       ...                ...
# ERR2208936                0.0           8.951373
# ERR2208974                0.0           3.851735
# ERR2208904                0.0          23.255255
# ERR2208951                0.0           0.000000
# ERR2208926                0.0          42.270817
#
# [91 rows x 60660 columns]

# %%
import pandas as pd
from glob import glob
import os

from rnanorm.datasets import load_toy_data
from rnanorm import FPKM, TPM, CPM, TMM 

# load the gene length
gtf_path = '/n/data1/hms/dbmi/zitnik/lab/users/was966/ITRP/GENCODE/release_44/HS.gencode.v44.annotation.gtf'
tpm = TPM(gtf_path).set_output(transform="pandas")

out_dir='/n/data1/hms/dbmi/zitnik/lab/users/was966/ITRP/fastaq/Gide/STAR/'
outs = glob(os.path.join(out_dir, "*ReadsPerGene.out.tab"))


counts=[]
for out in outs:
    ids = os.path.basename(out).replace('ReadsPerGene.out.tab', '')
    df = pd.read_csv(out,sep='\t', header=None)
    df.columns=['geneid', 'unstranded_counts', 'unstranded_counts_1st','unstranded_counts_2nd']
    df = df.iloc[4:].set_index('geneid')
    cts = df.unstranded_counts
    cts.name = ids
    counts.append(cts)

## counts, TPM, TMM
df_counts = pd.concat(counts,axis=1).T
df_tpm2 = tpm.fit_transform(df_counts)

df_tpm2
# Out:
# /home/was966/micromamba/envs/RNA/lib/python3.11/site-packages/rnanorm/methods/within_sample.py:135: UserWarning: X contains 8318 genes that are not in GTF /n/data1/hms/dbmi/zitnik/lab/users/was966/ITRP/GENCODE/release_44/HS.gencode.v44.annotation.gtf. This will result in NaN values for missing genes in the output.
#   warnings.warn(
#             ENSG00000223972.5  ENSG00000227232.5  ENSG00000278267.1  \
# ERR2208944                NaN          26.547470           0.000000
# ERR2208928                NaN          34.750253           3.109936
# ERR2208949                NaN          56.286392           0.000000
# ERR2208900                NaN          11.934054           0.000000
# ERR2208922                NaN           3.096825           2.121608
# ...                       ...                ...                ...
# ERR2208936                NaN           6.652523           0.000000
# ERR2208974                NaN          29.507736           0.000000
# ERR2208904                NaN          15.157477           1.142859
# ERR2208951                NaN          19.305981           0.000000
# ERR2208926                NaN          14.802990           0.000000
#
#             ENSG00000243485.5  ENSG00000284332.1  ENSG00000237613.2  \
# ERR2208944                0.0                0.0           0.146379
# ERR2208928                0.0                0.0           0.000000
# ERR2208949                0.0                0.0           0.384280
# ERR2208900                0.0                0.0           0.325428
# ERR2208922                0.0                0.0           0.000000
# ...                       ...                ...                ...
# ERR2208936                0.0                0.0           0.000000
# ERR2208974                0.0                0.0           2.712691
# ERR2208904                0.0                0.0           0.000000
# ERR2208951                0.0                0.0           0.377032
# ERR2208926                0.0                0.0           0.000000
#
#             ENSG00000268020.3  ENSG00000240361.2  ENSG00000186092.6  \
# ERR2208944                0.0                NaN                NaN
# ERR2208928                0.0                NaN                NaN
# ERR2208949                0.0                NaN                NaN
# ERR2208900                0.0                NaN                NaN
# ERR2208922                0.0                NaN                NaN
# ...                       ...                ...                ...
# ERR2208936                0.0                NaN                NaN
# ERR2208974                0.0                NaN                NaN
# ERR2208904                0.0                NaN                NaN
# ERR2208951                0.0                NaN                NaN
# ERR2208926                0.0                NaN                NaN
#
#             ENSG00000238009.6  ...  ENSG00000198886.2  ENSG00000210176.1  \
# ERR2208944           0.000000  ...         178.177001           0.000000
# ERR2208928           0.000000  ...         347.292722           0.000000
# ERR2208949           0.000000  ...         288.268834           2.262980
# ERR2208900           0.030419  ...         270.770713           1.642638
# ERR2208922           0.000000  ...        1468.762408           4.181720
# ...                       ...  ...                ...                ...
# ERR2208936           0.229726  ...         323.003012           0.000000
# ERR2208974           0.000000  ...         289.562361           2.662456
# ERR2208904           0.000000  ...         127.343381           0.563148
# ERR2208951           0.000000  ...          86.717246           0.000000
# ERR2208926           0.097589  ...        3175.696479          13.174466
#
#             ENSG00000210184.1  ENSG00000210191.1  ENSG00000198786.2  \
# ERR2208944           0.000000           0.000000          93.255448
# ERR2208928           0.000000           0.000000         297.489737
# ERR2208949           0.000000           0.000000         153.646599
# ERR2208900           1.440789           0.399092         171.827055
# ERR2208922           0.000000           0.000000         436.311255
# ...                       ...                ...                ...
# ERR2208936           0.000000           0.000000         164.153090
# ERR2208974           0.000000           0.000000         157.146608
# ERR2208904           0.658597           0.000000          71.667113
# ERR2208951           0.000000           0.000000          48.382433
# ERR2208926           3.081485           0.000000         905.024756
#
#             ENSG00000198695.2  ENSG00000210194.1  ENSG00000198727.2  \
# ERR2208944          60.498294                0.0          91.016424
# ERR2208928         184.890130                0.0         275.418755
# ERR2208949         112.127425                0.0         101.953099
# ERR2208900         145.833443                0.0          93.027900
# ERR2208922         357.787968                0.0         525.995147
# ...                       ...                ...                ...
# ERR2208936         146.735654                0.0         169.353650
# ERR2208974         116.874205                0.0         107.391942
# ERR2208904          57.434663                0.0          86.364500
# ERR2208951          26.044080                0.0          43.603727
# ERR2208926         550.271105                0.0        1118.093048
#
#             ENSG00000210195.2  ENSG00000210196.2
# ERR2208944                0.0          10.496234
# ERR2208928                0.0           0.000000
# ERR2208949                0.0           9.185036
# ERR2208900                0.0          42.086572
# ERR2208922                0.0          12.729648
# ...                       ...                ...
# ERR2208936                0.0          12.587617
# ERR2208974                0.0           5.403219
# ERR2208904                0.0          27.428622
# ERR2208951                0.0           0.000000
# ERR2208926                0.0          53.472834
#
# [91 rows x 60660 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.scatter(np.log2(df_tpm['ENSG00000198727.2']+1), np.log2(df_tpm2['ENSG00000198727.2']+1))
