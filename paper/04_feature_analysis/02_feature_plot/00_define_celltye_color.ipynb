# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style = 'white', font_scale=1.5)

from umap import UMAP
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE, Isomap, MDS, LocallyLinearEmbedding

import colorcet as cc
import math
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.patches import Rectangle


def plot_colortable(colors, *, ncols=4, sort_colors=True, anote = True, margin = 12, swatch_width = 48):

    cell_width = 230
    cell_height = 30
    swatch_width = swatch_width
    margin = margin

    # Sort colors by hue, saturation, value and name.
    if sort_colors is True:
        names = sorted(
            colors, key=lambda c: tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(c))))
    else:
        names = list(colors)

    n = len(names)
    nrows = math.ceil(n / ncols)

    width = cell_width * ncols + 2 * margin
    height = cell_height * nrows + 2 * margin
    dpi = 72

    fig, ax = plt.subplots(figsize=(width / dpi, height / dpi), dpi=dpi)
    fig.subplots_adjust(margin/width, margin/height,
                        (width-margin)/width, (height-margin)/height)
    ax.set_xlim(0, cell_width * ncols)
    ax.set_ylim(cell_height * (nrows-0.5), -cell_height/2.)
    ax.yaxis.set_visible(False)
    ax.xaxis.set_visible(False)
    ax.set_axis_off()

    for i, name in enumerate(names):
        row = i % nrows
        col = i // nrows
        y = row * cell_height

        swatch_start_x = cell_width * col
        text_pos_x = cell_width * col + swatch_width + 7

        ax.text(text_pos_x, y, name, fontsize=14,
                horizontalalignment='left',
                verticalalignment='center')

        ax.add_patch(
            Rectangle(xy=(swatch_start_x, y-9), width=swatch_width,
                      height=18, facecolor=colors[name], edgecolor='0.7')
        )

        if anote:
            ax.text(swatch_start_x, y, colors[name], fontsize=10,
                    horizontalalignment='left', color = 'white',
                    verticalalignment='center')

    return fig

# %%
dfc = pd.read_csv('../../02_extract_readouts/TCGA/02_readouts_celltype.csv', index_col=0)
dfc.head()
# Out:
#                        CANCER  Adipocyte  Apoptosis_pathway     Bcell  \
# bcr_patient_barcode
# TCGA-OR-A5KT        -0.853948  -0.049561           0.067183  0.018756
# TCGA-OR-A5J9        -0.854061  -0.073756           0.064157 -0.025874
# TCGA-OR-A5K0        -0.854023  -0.062112           0.050998 -0.005797
# TCGA-OR-A5L6        -0.853366  -0.046818           0.158754 -0.003958
# TCGA-OR-A5LT        -0.853587  -0.046864           0.147135  0.013808
#
#                      CD4_Tcell  CD8_Tcell  CPI_Response  CPI_effect  \
# bcr_patient_barcode
# TCGA-OR-A5KT         -0.043658  -0.048390      0.083360   -0.134035
# TCGA-OR-A5J9         -0.140530  -0.063277     -0.055122   -0.069229
# TCGA-OR-A5K0         -0.167273  -0.030240     -0.042876   -0.154139
# TCGA-OR-A5L6          0.000847  -0.056700     -0.030249   -0.154837
# TCGA-OR-A5LT         -0.120242  -0.055513     -0.034383   -0.155912
#
#                      Cytokine_chemokine  Cytotoxic_Tcell  ...    Stroma  \
# bcr_patient_barcode                                       ...
# TCGA-OR-A5KT                  -0.008558        -0.072593  ...  0.037289
# TCGA-OR-A5J9                   0.098089        -0.152360  ...  0.101554
# TCGA-OR-A5K0                   0.026000        -0.208526  ...  0.130620
# TCGA-OR-A5L6                   0.045585        -0.035811  ...  0.151876
# TCGA-OR-A5LT                   0.083958        -0.285978  ...  0.189860
#
#                      TGFb_pathway       TLS       TMB  Tcell_exclusion  \
# bcr_patient_barcode
# TCGA-OR-A5KT             0.093233  0.139817 -0.125032        -0.038299
# TCGA-OR-A5J9             0.072321 -0.067980 -0.152064        -0.048904
# TCGA-OR-A5K0             0.010347 -0.111355 -0.135933         0.030603
# TCGA-OR-A5L6            -0.020419  0.005885 -0.127582        -0.038786
# TCGA-OR-A5LT             0.029160 -0.141437 -0.124297        -0.082188
#
#                      Tcell_general      Treg       cDC       pDC  Reference
# bcr_patient_barcode
# TCGA-OR-A5KT             -0.143708 -0.048759  0.014876 -0.118702   0.951995
# TCGA-OR-A5J9             -0.213770  0.044493  0.039558 -0.125519   0.951651
# TCGA-OR-A5K0             -0.226085  0.036541  0.146706 -0.118289   0.951619
# TCGA-OR-A5L6             -0.183208  0.055888  0.042151 -0.107151   0.953562
# TCGA-OR-A5LT             -0.212599  0.024319 -0.029704 -0.105118   0.955235
#
# [5 rows x 46 columns]

# %%
palette = sns.color_palette(cc.glasbey, n_colors= len(dfc.columns[1:]))
palette = pd.Series(list(palette.as_hex())).sort_values().tolist()
mycolors = dict(zip(dfc.columns[1:], palette))

# %%
import sys
sys.path.insert(0, '/home/was966/Research/mims-conceptor/')
from conceptor.tokenizer import CONCEPT_palette, CONCEPT
#CONCEPT_palette.pop('CANCER')

# %%
GENESET_palette = CONCEPT.CelltypePathway.map(CONCEPT_palette).to_dict()
fig = plot_colortable(GENESET_palette, sort_colors = False, margin = 200)
fig.tight_layout()
fig.savefig('color_geneset.pdf')

# %%
fig = plot_colortable(CONCEPT_palette, sort_colors = False)
fig.savefig('color_celltype.pdf')

# %%
fig = plot_colortable(mcolors.CSS4_COLORS, sort_colors = True)
fig.savefig('color_color2pick.pdf')

# %%
CONCEPT['n_genes'] = CONCEPT.Genes.apply(lambda x:len(x.split(':')))
celltype_genes = CONCEPT.groupby('CelltypePathway').n_genes.sum().sort_values()
celltype_genes = celltype_genes.to_frame('total_num_genes')
celltype_genesets = CONCEPT.reset_index().groupby('CelltypePathway').GeneSet.size().to_frame(name = 'num_genesets')

from itertools import chain
def unique_genes(df):
    gls = df.Genes.apply(lambda x:x.split(':')).to_list()
    ugls = list(set(chain(*gls)))
    return  ':'.join(ugls)

celltype_unique_genes = CONCEPT.groupby('CelltypePathway').apply(unique_genes).to_frame('unique_genes')
celltype_num = celltype_genes.join(celltype_unique_genes).join(celltype_genesets)
celltype_num['total_num_unique_genes'] = celltype_num.unique_genes.apply(lambda x:len(x.split(':')))
celltype_num.head()
# Out:
#                       total_num_genes                           unique_genes  \
# CelltypePathway
# Stem                                4                   AVP:CD34:NRIP1:CRHBP
# Innate_lymphoid_cell                4                   LST1:PRMT9:ALDOC:LTB
# Hepatocyte                          5              ALDOB:APOH:APOC3:PCK1:TAT
# Pneumocyte                          6         PGC:CFTR:NAPSA:AGER:SPTB:ABCA3
# Mesothelial                         6  PRG4:UPK3B:CCDC80:PLA2G2A:CALB2:PTGIS
#
#                       num_genesets  total_num_unique_genes
# CelltypePathway
# Stem                             1                       4
# Innate_lymphoid_cell             1                       4
# Hepatocyte                       1                       5
# Pneumocyte                       1                       6
# Mesothelial                      1                       6

# %%
celltype_num.to_csv('./celltype_statistic.tsv', sep='\t')

# %%
celltype_num
# Out:
#                       total_num_genes  \
# CelltypePathway
# Stem                                4
# Innate_lymphoid_cell                4
# Hepatocyte                          5
# Pneumocyte                          6
# Mesothelial                         6
# pDC                                 7
# Platelet                            7
# Neutrophil                          7
# Reference                           8
# Erythrocyte                         8
# Naive_Tcell                         9
# Mast                                9
# Adipocyte                           9
# Immune_checkpoint                  13
# Monocyte                           14
# Memory_Tcell                       15
# TLS                                15
# Endothelial                        15
# Apoptosis_pathway                  16
# OS_effect                          16
# CPI_Response                       16
# Pancreatic                         18
# Epithelial                         20
# Stroma                             21
# Fibroblast                         25
# Granulocyte                        25
# NKcell                             26
# CD4_Tcell                          31
# Treg                               34
# Bcell                              34
# Tcell_exclusion                    38
# Cytotoxic_Tcell                    41
# IFNg_pathway                       42
# CPI_effect                         47
# cDC                                47
# PLFcell                            48
# Tcell_general                      51
# Myeloid                            56
# TGFb_pathway                       58
# TMB                                64
# Macrophage                         81
# Exhausted_Tcell                   100
# CD8_Tcell                         100
# Immune_score                      140
# Cytokine_chemokine                461
#
#                                                            unique_genes  \
# CelltypePathway
# Stem                                               AVP:CD34:NRIP1:CRHBP
# Innate_lymphoid_cell                               LST1:PRMT9:ALDOC:LTB
# Hepatocyte                                    ALDOB:APOH:APOC3:PCK1:TAT
# Pneumocyte                               PGC:CFTR:NAPSA:AGER:SPTB:ABCA3
# Mesothelial                       PRG4:UPK3B:CCDC80:PLA2G2A:CALB2:PTGIS
# pDC                         ASIP:CLEC4C:PTCRA:LILRA4:SCT:SLC12A3:LRRC26
# Platelet                         TMEM40:ITGB3:ACRBP:PF4:PPBP:GP9:TREML1
# Neutrophil               CEACAM3:FPR1:CSF3R:FCAR:SIGLEC5:FCGR3B:S100A12
# Reference                   RPL4:PSMB4:YWHAZ:GAPDH:ACTB:EEF2:UBC:HNRNPK
# Erythrocyte                      CA1:HBD:AHSP:TPM1:KCNN4:PAN3:ERMAP:HBB
# Naive_Tcell                 IL7R:LEF1:NELL2:CAMK4:TCF7:CCR7:MAL:TRABD2A
# Mast                            TPSAB1:TPSB2:CPA3:MS4A2:HDC:HPGDS:VWA5A
# Adipocyte             TCF21:ADIPOQ:UCP1:LEP:CIDEA:LHX8:FABP4:PRDM16:...
# Immune_checkpoint          PDCD1LG2:PDCD1:LAG3:TIGIT:CD274:CTLA4:HAVCR2
# Monocyte              FCN1:IER3:FCAR:CLEC4D:IL1B:CCL3:S100A8:MCEMP1:...
# Memory_Tcell          IL7R:TNFRSF4:CD84:STING1:AP3M2:CD40LG:AQP3:GPR...
# TLS                   CXCL13:CETP:LAT:SKAP1:CCR7:CXCR5:PTGDS:EIF1AY:...
# Endothelial           MYCT1:FLT4:ESAM:ERG:CDH5:KDR:CCL14:ICAM2:ESM1:...
# Apoptosis_pathway     MCL1:BAD:BAX:BCL2L2:BCL2L1:BID:CASP9:FASLG:CAS...
# OS_effect             SLAMF6:CD79A:CXCL13:CD3G:NREP:LTB:EFNB2:MAP4K1...
# CPI_Response          PCDH11X:BACH2:CXCL13:NELL2:UBAP1L:CLEC17A:CXCR...
# Pancreatic            MEIS1:FGB:ADCYAP1:STMN2:IRX2:HADH:RGS2:LEPR:CR...
# Epithelial            CITED4:SOX9:TFF2:CDH1:EPCAM:SLC12A2:SMIM22:KRT...
# Stroma                POSTN:SULF1:EDNRA:CDH11:MXRA5:PRRX1:DCN:THY1:B...
# Fibroblast            MMP3:MFAP5:EMILIN1:CYGB:RGS5:CSPG4:WNT2:NDUFA4...
# Granulocyte           EPX:PRTN3:HDC:ELANE:FUT9:IL4:CTSG:SIGLEC8:CCR3...
# NKcell                TNFRSF18:SELL:FCRL6:CCL4:LIM2:FCGR3A:KLRF1:IL2...
# CD4_Tcell             BACH2:TNFRSF4:IL17A:EOMES:SELL:CD4:IL2RA:SESN1...
# Treg                  LAIR2:LAYN:TNFRSF18:IL2RA:IKZF2:IL21R:RTKN2:CC...
# Bcell                 PNOC:IGHD:JSRP1:TCL1A:VPREB3:BTLA:CD72:BLK:IGH...
# Tcell_exclusion       LAMP2:CD63:RUVBL2:GPATCH4:FOS:PSAP:HLA-B:LGALS...
# Cytotoxic_Tcell       KLRK1:CD247:TRGC2:CD8B:KLRD1:KLF2:GZMA:KLRB1:C...
# IFNg_pathway          CCR5:EOMES:CXCR6:CCL5:IL2RG:GZMA:CXCL9:CD2:TBX...
# CPI_effect            CCR5:CD3G:CXCR6:CD247:GBP1:FCRL6:HS3ST3A1:CD8B...
# cDC                   CD209:LILRB4:FLT3:XRC1:SIGLEC6:HSD11B1:CD1E:CC...
# PLFcell               TOP2A:KIF11:CDC45:BLM:UNG:E2F8:UBE2C:AURKB:KIF...
# Tcell_general         CXCL3:CD3G:EOMES:CXCR6:KLRK1:UBASH3A:ADAM12:TR...
# Myeloid               P2RY12:CSF3R:C5AR1:LILRB4:MS4A4E:GPBAR1:HDC:MS...
# TGFb_pathway          CLDN3:FAM101B:IGFBP3:KIT:VIM:SOX9:CDH1:ADAM12:...
# TMB                   CDKN2B:RPA1:CDC45:APOBEC3A:E2F1:EME1:MCM4:ATM:...
# Macrophage            ALOX15:PALLD:PCED1B:CD209:DUOXA1:SYT17:SH3BP4:...
# Exhausted_Tcell       ADRB2:PARK7:CD27:SPATA20:SLC14A1:DHX58:IFIT3:E...
# CD8_Tcell             GRIK4:FABP5:APOBEC3C:HLA-DPB1:TRPS1:NAA40:SELL...
# Immune_score          TNFSF10:CD27:HLA-DPB1:SULF1:GZMA:CASP10:EMILIN...
# Cytokine_chemokine    CCL27:TNFSF10:IFNA7:EBI3:LEFTY2:IFNA2:WNT10B:T...
#
#                       num_genesets  total_num_unique_genes
# CelltypePathway
# Stem                             1                       4
# Innate_lymphoid_cell             1                       4
# Hepatocyte                       1                       5
# Pneumocyte                       1                       6
# Mesothelial                      1                       6
# pDC                              1                       7
# Platelet                         1                       7
# Neutrophil                       1                       7
# Reference                        1                       8
# Erythrocyte                      1                       8
# Naive_Tcell                      2                       8
# Mast                             2                       7
# Adipocyte                        1                       9
# Immune_checkpoint                5                       7
# Monocyte                         3                      14
# Memory_Tcell                     2                      12
# TLS                              2                      15
# Endothelial                      2                      13
# Apoptosis_pathway                2                      16
# OS_effect                        3                      14
# CPI_Response                     1                      16
# Pancreatic                       1                      18
# Epithelial                       2                      19
# Stroma                           1                      21
# Fibroblast                       4                      24
# Granulocyte                      4                      19
# NKcell                           5                      23
# CD4_Tcell                        4                      29
# Treg                             5                      20
# Bcell                            5                      29
# Tcell_exclusion                  2                      38
# Cytotoxic_Tcell                  6                      23
# IFNg_pathway                     4                      27
# CPI_effect                       2                      35
# cDC                              9                      35
# PLFcell                          3                      47
# Tcell_general                    4                      43
# Myeloid                          5                      50
# TGFb_pathway                     6                      51
# TMB                              8                      45
# Macrophage                       7                      75
# Exhausted_Tcell                  5                      93
# CD8_Tcell                        6                      89
# Immune_score                     4                     114
# Cytokine_chemokine               3                     251

# %%
CONCEPT['GeneSet_color'] = CONCEPT.index.map(GENESET_palette)
CONCEPT['CelltypePathway_color'] = CONCEPT.CelltypePathway.map(CONCEPT_palette)
CONCEPT.to_excel('SI_concept.xlsx')
