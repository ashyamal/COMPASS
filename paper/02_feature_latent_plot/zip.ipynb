# %%
import pandas as pd

# %%
df2d = pd.read_csv('celltype_space_2.csv.gzip', index_col=0, compression = 'gzip')

# %%
df2d
# Out:
#                                    cancer_type domain  \
# TCGA-02-0047$$Adipocyte                    GBM   TCGA
# TCGA-02-0055$$Adipocyte                    GBM   TCGA
# TCGA-02-2483$$Adipocyte                    GBM   TCGA
# TCGA-02-2485$$Adipocyte                    GBM   TCGA
# TCGA-02-2486$$Adipocyte                    GBM   TCGA
# ...                                        ...    ...
# Zhao_NatMed_2019-Pt100-ar-245$$pDC         GBM   ITRP
# Zhao_NatMed_2019-Pt101-ar-243$$pDC         GBM   ITRP
# Zhao_NatMed_2019-Pt102-ar-250$$pDC         GBM   ITRP
# Zhao_NatMed_2019-Pt103-ar-239$$pDC         GBM   ITRP
# Zhao_NatMed_2019-Pt104-ar-240$$pDC         GBM   ITRP
#
#                                               bcr_patient_barcode  \
# TCGA-02-0047$$Adipocyte                              TCGA-02-0047
# TCGA-02-0055$$Adipocyte                              TCGA-02-0055
# TCGA-02-2483$$Adipocyte                              TCGA-02-2483
# ...
